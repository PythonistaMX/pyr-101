# %% [markdown]
# <a href="https://www.pythonista.io"> <img src="img/pythonista.png"></a>

# %% [markdown]
# # Gestión de archivos CSV

# %% [markdown]
# ## Funciones de directorio.

# %% [markdown]
# ### La función ```getwd()```.

# %%
getwd()

# %% [markdown]
# ### La función ```setwd()```.
#
#
# ```
# setwd("<ruta">)
# ```

# %% [markdown]
# **Ejemplo:**

# %%
getwd()

# %%
actual <-getwd()

# %%
setwd("../")

# %%
getwd()

# %%
setwd(actual)

# %%
getwd()

# %% [markdown]
# ## La familia de funciones ```write()```.

# %%
methods(write)

# %% [markdown]
# ### La función ```write.csv()```.
#
# ```
# write.csv(<df>, "<ruta>")
# ```

# %% [markdown]
# **Ejemplo:**

# %%
nomina <- data.frame(nombre=c("Juan", "Felipe", "María", "Alberto"),
    apellido=c("Pérez", "López", "Sánchez", "Gutiérrez"),
    puesto=c("Gerente", "Director", "Contadora", "Auxiliar"),
    sueldo= c(30000, 25000, 15000, 10000))

# %%
write.csv(nomina, "nomina.csv")

# %% [markdown]
# ## La función ```read.csv()```.

# %%
nomina_2= read.csv("nomina.csv")

# %%
nomina_2

# %%
nvidia <- read.csv("https://query1.finance.yahoo.com/v7/finance/download/NVDA?period1=1576598969&period2=1608221369&interval=1d&events=history&includeAdjustedClose=true")

# %%
nvidia

# %%
salud <- read.csv("data/201214COVID19MEXICO.csv")

# %%
salud
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO ORIGEN SECTOR ENTIDAD_UM SEXO
# 1       2020-12-14          166d9e      2      12     26         2
# 2       2020-12-14          0d4821      1       4     26         1
# 3       2020-12-14          0990e9      2       4     12         1
# 4       2020-12-14          172400      2       4     21         1
# 5       2020-12-14          1804fa      2       4     23         2
# 6       2020-12-14          0bfa2c      2       9      9         2
# 7       2020-12-14          1dcf69      1      12      9         2
# 8       2020-12-14          02ab03      2      12     26         1
# 9       2020-12-14          11c483      1      12     29         1
# 10      2020-12-14          156b1d      1       9      9         1
# 11      2020-12-14          02d87b      2      12      2         2
# 12      2020-12-14          05f3d3      1      12      9         2
# 13      2020-12-14          058df2      2      12     21         2
# ...

# %%
colnames(salud)
# Out:
#  [1] "FECHA_ACTUALIZACION"   "ID_REGISTRO"           "ORIGEN"
#  [4] "SECTOR"                "ENTIDAD_UM"            "SEXO"
#  [7] "ENTIDAD_NAC"           "ENTIDAD_RES"           "MUNICIPIO_RES"
# [10] "TIPO_PACIENTE"         "FECHA_INGRESO"         "FECHA_SINTOMAS"
# [13] "FECHA_DEF"             "INTUBADO"              "NEUMONIA"
# [16] "EDAD"                  "NACIONALIDAD"          "EMBARAZO"
# [19] "HABLA_LENGUA_INDIG"    "INDIGENA"              "DIABETES"
# [22] "EPOC"                  "ASMA"                  "INMUSUPR"
# [25] "HIPERTENSION"          "OTRA_COM"              "CARDIOVASCULAR"
# [28] "OBESIDAD"              "RENAL_CRONICA"         "TABAQUISMO"
# [31] "OTRO_CASO"             "TOMA_MUESTRA_LAB"      "RESULTADO_LAB"
# [34] "TOMA_MUESTRA_ANTIGENO" "RESULTADO_ANTIGENO"    "CLASIFICACION_FINAL"
# [37] "MIGRANTE"              "PAIS_NACIONALIDAD"     "PAIS_ORIGEN"
# [40] "UCI"

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2020.</p>
